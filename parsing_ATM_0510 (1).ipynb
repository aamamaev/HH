# %%
import urllib.request
from bs4 import BeautifulSoup
import warnings
import datetime
warnings.simplefilter("ignore")
from datetime import datetime

from collections import namedtuple
import pickle
import pandas as pd

from IPython.display import clear_output
from selenium import webdriver
from time import sleep
import json
from math import radians, cos, sin, asin, sqrt
import copy

import concurrent.futures
from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor
import multiprocessing
import numpy as np
import pyodbc
from sqlalchemy import create_engine
import time

# %% [markdown]
# ### Загрузка таблицы с адресами

# %%
engine = create_engine('oracle+cx_oracle://RP_USERS:blurry_3RP_USERS@RISKTE')

atm = pd.read_sql_query("""
                            select *
                            from MAA_ATM
                            """, engine)

# %%
pickle.dump(atm, open('mta.dat','wb'))

# %%
atm.head()
# Out:
#    atm_caid atm_terminal                          full_address  \
# 0  Alfa Iss       152789         138 MICHURINA STR      SAMARA
# 1      VB24       382582  D. 7, UL. SOVETSKAYA   BELOKURIKHA G
# 2      VB24       388084  D. 26/24, PR-KT INDUSTRSANKT-PETERBU
# 3      VB24       387738         D. 20, KORP. 1, PR-KT MOMSK G
# 4  55034001     55034001      RBA ATM 34001          KRASNODAR
#
#                    address              city address_rus  lat  long
# 0        138 MICHURINA STR            SAMARA              NaN   NaN
# 1     D. 7, UL. SOVETSKAYA       BELOKURIKHA              NaN   NaN
# 2  D. 26/24, PR-KT INDUSTR  SAINT PETERSBURG              NaN   NaN
# 3  D. 20, KORP. 1, PR-KT M              OMSK              NaN   NaN
# 4            RBA ATM 34001         KRASNODAR              NaN   NaN

# %%
atm
# Out:
#            atm_caid atm_terminal                atm_card_acceptor_name
# 0          Alfa Iss       152789         138 MICHURINA STR      SAMARA
# 1              VB24       382582  D. 7, UL. SOVETSKAYA   BELOKURIKHA G
# 2              VB24       388084  D. 26/24, PR-KT INDUSTRSANKT-PETERBU
# 3              VB24       387738         D. 20, KORP. 1, PR-KT MOMSK G
# 4          55034001     55034001      RBA ATM 34001          KRASNODAR
# 5              VB24       380413      D. 11, UL. SOVETSKAYA  ZARYA MKR
# 6          Alfa Iss       210726         11/23 PYATNITSKAYA STR.MOSCOW
# 7       GAZPROMBANK       405289         GAL. AEROPORT          MOSKVA
# 8              VB24       387390       D. 4, UL. LENINA       REUTOV G
# 9          55034331     55034331         RBA ATM 34331          MOSKVA
# 10             VB24       382814      D. 5A, UL. MELANZHEVAYAIVANOVO G
# 11         Alfa Iss       156028         4 MASTERKOVA STR.      MOSCOW
# 12         Alfa Iss       210406         13A DMITROVSKOE HIGHWAYMOSKVA
# 13         Alfa Iss       156058         4 LOKOMOTIVNIY PASS.   MOSCOW
# 14             VB24       389660    D. 3, UL. GORNAYA KARUSESTOSADOK S
# 15         55024471     55024471      RBA ATM 24471          KRASNODAR
# 16             VB24       383646        D. 22, UL. MOSKOVSKAYA SOCHI G
# 17         Alfa Iss       502870      9B RABOCHE-KRESTYAN    VOLGOGRAD
# 18      GAZPROMBANK       411068        UL. SADOVAJA, 20       KASHIRA
# 19      GAZPROMBANK       406943      27 VOLG,EREMENKO.54    VOLGOGRAD
# 20             VB24       389254     D. 10, UL. 60 LET SSSR FRYAZINO G
# 21         55017551     55017551         RBA ATM 17551          MOSKVA
# 22             VB24       399096     D. 32, MKR. DAVYDOVSKIIKOSTROMA G
# 23             VB24       383689        D. 18, UL. LENINGRADSKAMUROM G
# 24         Alfa Iss       210632         2 TAGANSKAYA STR.      MOSCOW
# 25             VB24       389841       D. 56, UL. PROFSOUZNAYAMOSKVA G
# 26         Alfa Iss       155228         28 DOMODEDOVSKAYA ST.  MOSCOW
# 27         55017291     55017291  RBA ATM 17291          ST-PETERSBURG
# 28         55016601     55016601       RBA ATM 16601          MYTISCHI
# 29         Alfa Iss       220202          2 AKSAYSKIY AVE        AKSAY
# ...             ...          ...                                   ...
# 10213  120703364666      1479027          ATM-01479027 URALSIB   YEISK
# 10214          VB24       388278         D. 129, PR-KT LENINA   TULA G
# 10215          VB24       387632       D. 1820, KORP. 1, SH. ZMOSKVA G
# 10216      ATM 6363     S1AM6363      GURIANOVA 20           BELOUSOVO
# 10217   GAZPROMBANK       408452        BRN POCH MAGN LENIN    BRJANSK
# 10218          VB24       382011         D. 20, PR-KT KIROVA    LUGA G
# 10219      Alfa Iss       755058    6 KIROVSKAYA STR.      ARKHANGELSK
# 10220      ATM 1402     S1AM1402          SOVETSKAYA PL. 9       RYLSK
# 10221      Alfa Iss       502747       33B KUZNETSKIY AVE     KEMEROVO
# 10222          VB24       380935  D. 71, PR-KT NEVSKII   SANKT-PETERBU
# 10223      Alfa Iss       755176         7A STROITELEY AV.      ENGELS
# 10224          VB24       389518       D. 14/7, PL. SUHAREVSKAMOSKVA G
# 10225   GAZPROMBANK       442990    ST.M. POKRYSHKINA      NOVOSIBIRSK
# 10226   GAZPROMBANK       405166         RJAZANSKIJ PR, 28.1    MOSKVA
# 10227          VB24       388822   D. 7A, PR-KT LENINA    NOVOROSSIYSK
# 10228          VB24       389308        D. 96, PR-KT STROITELEIPENZA G
# 10229      55027761     55027761         RBA ATM 27761          SAMARA
# 10230   GAZPROMBANK       402559            UFA CJURUPY 97         UFA
# 10231      Alfa Iss       221198         147 KIROVA AVE         SAMARA
# 10232          VB24       397509  D. 120, PR-KT LENINSKIISANKT-PETERBU
# 10233          VB24       387658      D. 119, UL. LEZHNEVSKAYIVANOVO G
# 10234          VB24       382087     D. 92, UL. GOR'KOGO    TOLYATTI G
# 10235          VB24       387622        D. 76, PR-KT YAMASHEVA KAZAN G
# 10236      ATM 3559     S1AM3559          ORLOVSKAYA 109         ORLOV
# 10237          VB24       380234   D. 9, PR-KT 60 LET OKTYSHCHELKOVO G
# 10238      Alfa Iss       221176         10 GEOLOGICHESKAYA     SURGUT
# 10239          VB24       389129   D. 44, UL. KUIBYSHEVA  EKATERINBURG
# 10240            88           88         ABB 5 SPORTIVNAYA      SAMARA
# 10241          VB24       383603   V/CH 32755, UL. VOENNNYZVEZDNYY PGT
# 10242      55014251     55014251    RBA ATM 14251          CHELYABINSK
#
# [10243 rows x 3 columns]

# %%
atm.columns  = ['atm_caid','atm_terminal','full_address']

# %%
atm['address'] = atm.full_address.apply(lambda x: x[:23].strip())

# %%
atm['city'] = atm.full_address.apply(lambda x: x[23:].strip()).apply(lambda x: x[:-2] if x.endswith(' G') else x)

# %%
def transform(x):
    dictionary = {"MOSKVA": "MOSCOW",
                  "SANKT-PETERBU": "SAINT PETERSBURG",
                  'S.-PETERBURG':  "SAINT PETERSBURG",
                  'ST-PETERSBURG': "SAINT PETERSBURG",
                  'ST PETERSBURG': "SAINT PETERSBURG"}
    for key, value in dictionary.items():
        x = x.replace(key, value)
    return x

# %%
atm.city = atm.city.map(transform)

# %%
atm['address_rus'] = ''
atm['lat'] = np.nan
atm['long'] = np.nan

# %% [markdown]
# # Парсер открытой информации из HeadHanter

# %%
def log_progress(sequence, every=10):
    for index, item in enumerate(sequence):
        if index % every == 0:
            clear_output()
            print(index)
        yield item

# %%
pickle.dump(atm,open('atm_info.df','wb'))

# %%
def parsing(atm):
    driver = webdriver.Chrome('chromedriver.exe')
    url = 'https://yandex.ru/maps/213/moscow/?ll=37.530858%2C55.640315&z=12&mode=search&text='
    for i, atmi in log_progress(atm.iterrows()):
        urli = url + ' '.join([atmi.address, atmi.city]).replace(' ', '%20')
        driver.get(urli)
        try: 
            element = driver.find_element_by_xpath("//div[@class='clipboard__action-wrapper _inline']")
            atm.at[i, 'lat'],  atm.at[i, 'long'] = list(map(float, element.text.split(',')))

            addr_part1 = driver.find_element_by_xpath("//div[@class='card-title-view__title']")
            addr_part2 = driver.find_element_by_xpath("//div[@class='toponym-card-view__description']")
            atm.at[i, 'adress'] = addr_part1.text + ', ' + addr_part2.text 
        except:
            pass
        time.sleep(0.5)

# %%
atm
# Out:
#            atm_caid atm_terminal                atm_card_acceptor_name
# 0          Alfa Iss       152789         138 MICHURINA STR      SAMARA
# 1              VB24       382582  D. 7, UL. SOVETSKAYA   BELOKURIKHA G
# 2              VB24       388084  D. 26/24, PR-KT INDUSTRSANKT-PETERBU
# 3              VB24       387738         D. 20, KORP. 1, PR-KT MOMSK G
# 4          55034001     55034001      RBA ATM 34001          KRASNODAR
# 5              VB24       380413      D. 11, UL. SOVETSKAYA  ZARYA MKR
# 6          Alfa Iss       210726         11/23 PYATNITSKAYA STR.MOSCOW
# 7       GAZPROMBANK       405289         GAL. AEROPORT          MOSKVA
# 8              VB24       387390       D. 4, UL. LENINA       REUTOV G
# 9          55034331     55034331         RBA ATM 34331          MOSKVA
# 10             VB24       382814      D. 5A, UL. MELANZHEVAYAIVANOVO G
# 11         Alfa Iss       156028         4 MASTERKOVA STR.      MOSCOW
# 12         Alfa Iss       210406         13A DMITROVSKOE HIGHWAYMOSKVA
# 13         Alfa Iss       156058         4 LOKOMOTIVNIY PASS.   MOSCOW
# 14             VB24       389660    D. 3, UL. GORNAYA KARUSESTOSADOK S
# 15         55024471     55024471      RBA ATM 24471          KRASNODAR
# 16             VB24       383646        D. 22, UL. MOSKOVSKAYA SOCHI G
# 17         Alfa Iss       502870      9B RABOCHE-KRESTYAN    VOLGOGRAD
# 18      GAZPROMBANK       411068        UL. SADOVAJA, 20       KASHIRA
# 19      GAZPROMBANK       406943      27 VOLG,EREMENKO.54    VOLGOGRAD
# 20             VB24       389254     D. 10, UL. 60 LET SSSR FRYAZINO G
# 21         55017551     55017551         RBA ATM 17551          MOSKVA
# 22             VB24       399096     D. 32, MKR. DAVYDOVSKIIKOSTROMA G
# 23             VB24       383689        D. 18, UL. LENINGRADSKAMUROM G
# 24         Alfa Iss       210632         2 TAGANSKAYA STR.      MOSCOW
# 25             VB24       389841       D. 56, UL. PROFSOUZNAYAMOSKVA G
# 26         Alfa Iss       155228         28 DOMODEDOVSKAYA ST.  MOSCOW
# 27         55017291     55017291  RBA ATM 17291          ST-PETERSBURG
# 28         55016601     55016601       RBA ATM 16601          MYTISCHI
# 29         Alfa Iss       220202          2 AKSAYSKIY AVE        AKSAY
# ...             ...          ...                                   ...
# 10213  120703364666      1479027          ATM-01479027 URALSIB   YEISK
# 10214          VB24       388278         D. 129, PR-KT LENINA   TULA G
# 10215          VB24       387632       D. 1820, KORP. 1, SH. ZMOSKVA G
# 10216      ATM 6363     S1AM6363      GURIANOVA 20           BELOUSOVO
# 10217   GAZPROMBANK       408452        BRN POCH MAGN LENIN    BRJANSK
# 10218          VB24       382011         D. 20, PR-KT KIROVA    LUGA G
# 10219      Alfa Iss       755058    6 KIROVSKAYA STR.      ARKHANGELSK
# 10220      ATM 1402     S1AM1402          SOVETSKAYA PL. 9       RYLSK
# 10221      Alfa Iss       502747       33B KUZNETSKIY AVE     KEMEROVO
# 10222          VB24       380935  D. 71, PR-KT NEVSKII   SANKT-PETERBU
# 10223      Alfa Iss       755176         7A STROITELEY AV.      ENGELS
# 10224          VB24       389518       D. 14/7, PL. SUHAREVSKAMOSKVA G
# 10225   GAZPROMBANK       442990    ST.M. POKRYSHKINA      NOVOSIBIRSK
# 10226   GAZPROMBANK       405166         RJAZANSKIJ PR, 28.1    MOSKVA
# 10227          VB24       388822   D. 7A, PR-KT LENINA    NOVOROSSIYSK
# 10228          VB24       389308        D. 96, PR-KT STROITELEIPENZA G
# 10229      55027761     55027761         RBA ATM 27761          SAMARA
# 10230   GAZPROMBANK       402559            UFA CJURUPY 97         UFA
# 10231      Alfa Iss       221198         147 KIROVA AVE         SAMARA
# 10232          VB24       397509  D. 120, PR-KT LENINSKIISANKT-PETERBU
# 10233          VB24       387658      D. 119, UL. LEZHNEVSKAYIVANOVO G
# 10234          VB24       382087     D. 92, UL. GOR'KOGO    TOLYATTI G
# 10235          VB24       387622        D. 76, PR-KT YAMASHEVA KAZAN G
# 10236      ATM 3559     S1AM3559          ORLOVSKAYA 109         ORLOV
# 10237          VB24       380234   D. 9, PR-KT 60 LET OKTYSHCHELKOVO G
# 10238      Alfa Iss       221176         10 GEOLOGICHESKAYA     SURGUT
# 10239          VB24       389129   D. 44, UL. KUIBYSHEVA  EKATERINBURG
# 10240            88           88         ABB 5 SPORTIVNAYA      SAMARA
# 10241          VB24       383603   V/CH 32755, UL. VOENNNYZVEZDNYY PGT
# 10242      55014251     55014251    RBA ATM 14251          CHELYABINSK
#
# [10243 rows x 3 columns]

# %%
parsing(atm)
# Out:
# 50
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-416-ae214f43a000> in <module>()
# ----> 1 parsing(atm)
#
# <ipython-input-415-6c42bac08029> in parsing(atm)
#       4     for i, atmi in log_progress(atm.iterrows()):
#       5         urli = url + ' '.join([atmi.address, atmi.city]).replace(' ', '%20')
# ----> 6         driver.get(urli)
#       7         try:
#       8             element = driver.find_element_by_xpath("//div[@class='clipboard__action-wrapper _inline']")
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     330         Loads a web page in the current browser session.
#     331         """
# --> 332         self.execute(Command.GET, {'url': url})
#     333
#     334     @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     318         response = self.command_executor.execute(driver_command, params)
#     319         if response:
# --> 320             self.error_handler.check_response(response)
#     321             response['value'] = self._unwrap_value(
#     322                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=69.0.3497.100)
#   (Driver info: chromedriver=2.40.565498 (ea082db3280dd6843ebfb08a625e3eb905c4f5ab),platform=Windows NT 6.1.7601 SP1 x86_64)

# %%
atm1 = atm[atm.lat.isnull() & atm.atm_caid.isin({'VB24','GAZPROMBANK', 'Alfa Iss', 'Alfa Acq'})]

# %%
url  = 'https://yandex.ru/maps/213/moscow/?ll=37.628056%2C55.744059&z=16&mode=search&ol=geo&ouri=ymapsbm1%3A%2F%2Fgeo%3Fll%3D37.628063%252C55.744061%26spn%3D0.001000%252C0.001000%26text%3D11%252F23%252C%2520Pyatnitskaya%2520Street%252C%2520Moscow%252C%2520Russia%2520'

# %%
url2 = 'https://yandex.ru/maps/10668/murom/?ll=41.973135%2C55.526857&z=16&mode=search&text=D.%2018%2C%20UL.%20LENINGRADSKA%20MUROM&sll=37.657682%2C55.740882&sspn=0.023303%2C0.006283'

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %%
driver.get(url2)

# %% [markdown]
# ## Парсинг остановок и метро

# %%
sections = driver.find_elements_by_xpath("//div[@class='masstransit-stops-view']//div[@class='card-dropdown-view__count']")
lens = [int(x.text)+1 for x in sections]

sections = driver.find_elements_by_xpath("//div[@class='masstransit-stops-view']//div[@class='card-dropdown-view__control']")
# раскрываем выпадающие списки
for x in sections[::-1]: x.click()

sections = driver.find_elements_by_xpath("//div[@class='masstransit-stops-view']//div[@class='masstransit-stops-view__stop-name']")
names = [x.text for x in sections] 

sections = driver.find_elements_by_xpath("//div[@class='masstransit-stops-view']//div[@class='masstransit-stops-view__stop-distance']")
distances = [x.text for x in sections] 

if len(lens) == 1: 
    stations = list(zip(names, distances))
else:
    metro  = list(zip(names, distances))[:lens[0]]
    bus_stations = list(zip(names, distances))[lens[0]:]

# %% [markdown]
# ## Парсинг бизнес объектов  если их меньше пяти

# %%
sections = driver.find_elements_by_xpath("//div[@class='businesses-list-view']//div[@class='card-snippet-view__title']")

# %%
businesses_names = [x.text for x in sections]

# %%
businesses_names
# Out:
# ['Банк ВТБ, банкомат',
#  'Галатея. салон красоты',
#  'Аленький цветочек',
#  'Вербовский',
#  'Центрофинанс']

# %%
sections = driver.find_elements_by_xpath("//div[@class='businesses-list-view']//div[@class='card-snippet-view__description']")

# %%
businesses_categoties = [x.text for x in sections]

# %%
businesses  = list(zip(businesses_names, businesses_categoties))

# %% [markdown]
# ## Парсинг бизнес объектов  если их больше пяти

# %%
sections = driver.find_elements_by_xpath("//div[@class='businesses-list-view__show-all-link']")

# %%
sections[0].click()

# %%
sections = driver.find_elements_by_xpath("//a[@class='search-business-snippet-view__title']")

# %%
businesses_names = [x.text for x in sections]

# %%
sections = driver.find_elements_by_xpath("//div[@class='search-business-snippet-view__categories']")

# %%
businesses_categoties = [x.text for x in sections]

# %%
businesses = list(zip(businesses_names, businesses_categoties))

# %% [markdown]
# ## Переход обратно со страницы бизнес объектов

# %%
sections = driver.find_elements_by_xpath("//div[@class='sidebar-panel-header-back-view__icon']")

# %%
sections[0].click()

# %%
driver.find_elements_by_xpath("//div[@class='catalog-small-item-view__icon']")[0].click()

# %%
sections = driver.find_elements_by_xpath("//a[@class='search-business-snippet-view__title']")

# %%
eat_names = [x.text for x in sections]

# %%
eat_names
# Out:
# ['Находка', 'Кафе']

# %%
sections = driver.find_elements_by_xpath("//a[@class='search-business-snippet-view__title _with-badge']")

# %%
eat_names = [x.text for x in sections]

# %%
eat_names
# Out:
# ['SushiМясо']

# %%
card-snippet-view__description

# %%
get_html('https://yandex.ru/maps/213/moscow/?ll=37.530858%2C55.640315&z=12&mode=search&text=')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# C:\ProgramData\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# C:\ProgramData\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# C:\ProgramData\Anaconda3\lib\http\client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in connect(self)
#    1391
# -> 1392             super().connect()
#    1393
#
# C:\ProgramData\Anaconda3\lib\http\client.py in connect(self)
#     935         self.sock = self._create_connection(
# --> 936             (self.host,self.port), self.timeout, self.source_address)
#     937         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# C:\ProgramData\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     703     err = None
# --> 704     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     705         af, socktype, proto, canonname, sa = res
#
# C:\ProgramData\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11004] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-217-b9655bfe57d7> in <module>()
# ----> 1 get_html('https://yandex.ru/maps/213/moscow/?ll=37.530858%2C55.640315&z=12&mode=search&text=')
#
# <ipython-input-216-a650315fe9d3> in get_html(url)
#       1 def get_html(url):
# ----> 2     response = urllib.request.urlopen(url)
#       3     return response.read()
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
# -> 1320                 raise URLError(err)
#    1321             r = h.getresponse()
#    1322         except:
#
# URLError: <urlopen error [Errno 11004] getaddrinfo failed>

# %%
for i, atmi in log_progress(atm1.iterrows()):
    urli = url + atmi.adress_eng.replace(' ', '%20')
    driver.get(urli)
    try: 
        element = driver.find_element_by_xpath("//div[@class='clipboard__action-wrapper _inline']")
        atm.at[i, 'lat'],  atm.at[i, 'long'] = list(map(float, element.text.split(',')))
        
        addr_part1 = driver.find_element_by_xpath("//div[@class='card-title-view__title']")
        addr_part2 = driver.find_element_by_xpath("//div[@class='toponym-card-view__description']")
        atm.at[i, 'adress'] = addr_part1.text + ', ' + addr_part2.text 
    except:
        pass
# Out:
# 9000

# %%
def get_html(url):
    response = urllib.request.urlopen(url)
    return response.read()

# %%
pickle.dump(atm1,open('atm1.df','wb'))

# %%
for i, atmi in log_progress(atm.iterrows()):
    urli = url + atmi.adress_eng.replace(' ', '%20')
    html = get_html(urli)
    soup = BeautifulSoup(html)
    try: 
        coord = soup.find('div', class_='clipboard__action-wrapper _inline').text
        atm.at[i, 'lat'],  atm.at[i, 'long'] = list(map(float, coord.split(',')))

        coord = soup.find('div', class_='card-title-view__title').text
        coord = soup.find('div', class_='toponym-card-view__description').text

        atm.at[i, 'adress'] = addr_part1.text + ', ' + addr_part2.text 
    except:
        pass
# Out:
# 0
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
#
# C:\ProgramData\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# C:\ProgramData\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# C:\ProgramData\Anaconda3\lib\http\client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in connect(self)
#    1391
# -> 1392             super().connect()
#    1393
#
# C:\ProgramData\Anaconda3\lib\http\client.py in connect(self)
#     935         self.sock = self._create_connection(
# --> 936             (self.host,self.port), self.timeout, self.source_address)
#     937         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# C:\ProgramData\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     703     err = None
# --> 704     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     705         af, socktype, proto, canonname, sa = res
#
# C:\ProgramData\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11004] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-143-7b03c83935d7> in <module>()
#       1 for i, atmi in log_progress(atm.iterrows()):
#       2     urli = url + atmi.adress_eng.replace(' ', '%20')
# ----> 3     html = get_html(urli)
#       4     soup = BeautifulSoup(html)
#       5     try:
#
# <ipython-input-141-a650315fe9d3> in get_html(url)
#       1 def get_html(url):
# ----> 2     response = urllib.request.urlopen(url)
#       3     return response.read()
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                           encode_chunked=req.has_header('Transfer-encoding'))
#    1319             except OSError as err: # timeout error
# -> 1320                 raise URLError(err)
#    1321             r = h.getresponse()
#    1322         except:
#
# URLError: <urlopen error [Errno 11004] getaddrinfo failed>
